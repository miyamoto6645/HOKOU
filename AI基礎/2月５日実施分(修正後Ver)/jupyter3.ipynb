# %%
{{
  "nbformat"：4、
  "nbformat_minor"：0、
  "メタデータ"：{
    「コラボ」：{
      "名前"： "分析.ipynb"、
      「来歴」：[]、
      "collapsed_sections"：[]
    }、
    "kernelspec"：{
      "名前"： "python3"、
      "display_name"： "Python 3"
    }、
    "language_info"：{
      "名前"： "python"
    }、
    「アクセラレータ」：「GPU」
  }、
  「セル」：[
    {{
      "cell_type"： "マークダウン"、
      "メタデータ"：{
        "id"： "1wOGTleTx_Za"
      }、
      "ソース"： [
        "osetiをインストールする\ n"、
        "\ n"、
        「オセティとは\ n」、
        「東北大学の乾・鈴木研究室の選択で公開された日本語評価評価を評価分析（加ネガポジ楽）サンフランシスコオセティを公開しました。評価極（接近/ネガ越）のスコアを計算するです。」
      ]
    }、
    {{
      "cell_type"： "コード"、
      "メタデータ"：{
        "id"： "Glu5Ohb-V3RI"
      }、
      "ソース"： [
        "%% capture capt \ n"、
        "\ n"、
        "＃MeCabのインストール\ n"、
        "！apt install mecab libmecab-dev mecab-ipadic-utf8 \ n"、
        "！pip install mecab-python3 \ n"、
        "\ n"、
        "＃mecab-ipadic-NEologdのインストール\ n"、
        "！apt install git make curl xz-utils file \ n"、
        "！git clone --depth 1 https://github.com/neologd/mecab-ipadic-neologd.git \ n"、
        "！echo yes | mecab-ipadic-neologd / bin / install-mecab-ipadic-neologd -n -a \ n"、
        "\ n"、
        "＃参照：https：//qiita.com/Fulltea/items/90f6ebe6dcceaf64eaef \ n"、
        "＃参照：https：//qiita.com/SUZUKI_Masaya/items/685000d569452585210c \ n"、
        "\ n"、
        "！ln -s / etc / mecabrc / usr / local / etc / mecabrc \ n"、
        "＃参照：https：//qiita.com/Naritoshi/items/8f55d7d5cce9ce414395"
      ]、
      "execution_count"：null、
      「出力」：[]
    }、
    {{
      "cell_type"： "コード"、
      "メタデータ"：{
        "id"： "9MN3Hg1OjsQx"、
        「コラボ」：{
          "base_uri"： "https：// localhost：8080 /"
        }、
        "outputId"： "05043735-1095-4b6d-ec36-a2d92ee197c8"
      }、
      "ソース"： [
        「pipinstalloseti」
      ]、
      "execution_count"：null、
      「出力」：[
        {{
          "output_type"： "stream"、
          "名前"： "stdout"、
          "文章"： [
            「要件はすでに満たされています：/usr/local/lib/python3.7/dist-packages（0.2）のoseti \ n」、
            「要件はすでに満たされています：/usr/local/lib/python3.7/dist-packagesのsengiri（osetiから）（0.2.1）\ n」、
            「要件はすでに満たされています：/usr/local/lib/python3.7/dist-packagesのneologdn（osetiから）（0.5.1）\ n」、
            「要件はすでに満たされています：/usr/local/lib/python3.7/dist-packagesのmecab-python3（osetiから）（1.0.4）\ n」、
            「要件はすでに満たされています：/usr/local/lib/python3.7/dist-packagesの絵文字（sengiri-> osetiから）（1.6.1）\ n」
          ]
        }
      ]
    }、
    {{
      "cell_type"： "マークダウン"、
      "メタデータ"：{
        "id"： "MgGJsOqayGLS"
      }、
      "ソース"： [
        "極性を評価と文部分の評価評価。\ n"、
        "\ n"、
        "こんなのでは[-1、1]でプラスンが最高にありで、マイナス値が最高にネガ苦ってます。\ n"、
        "\ n"、
        「こんなの計算は、今用言ごとに思う（+1）！ /マッチした単語・用言の数でスコアを。\ n "、
        "\ n"、
        「ここて刻された楽しかったしなっます。 = 0.3333なります。\ n "、
        "\ n"、
        「あり、「ない」や「ぬ」この否定表現ありと極性の反転反転ます。」
      ]
    }、
    {{
      "cell_type"： "コード"、
      "メタデータ"：{
        "id"： "p3a3hCsQxpwz"、
        「コラボ」：{
          "base_uri"： "https：// localhost：8080 /"
        }、
        "outputId"： "a726f3c0-a40c-4e53-f818-c409de883ac8"
      }、
      "ソース"： [
        "import oseti \ n"、
        "\ n"、
        "analyzer = oseti.Analyzer（）\ n"、
        "analyzer.analyze（ '天国で待った。'）\ n"、
        "＃=> [1.0] \ n"
      ]、
      "execution_count"：null、
      「出力」：[
        {{
          "output_type"： "execute_result"、
          "データ"： {
            "テキスト/プレーン"：[
              「[1.0]」
            ]
          }、
          "メタデータ"：{}、
          "execution_count"：3
        }
      ]
    }、
    {{
      "cell_type"： "コード"、
      "メタデータ"：{
        "id"： "BW-uWyM7zAQh"、
        「コラボ」：{
          "base_uri"： "https：// localhost：8080 /"
        }、
        "outputId"： "b3e5a501-8c20-4ffa-a244-1351abb6dee8"
      }、
      "ソース"： [
        "analyzer = oseti.Analyzer（）\ n"、
        "analyzer.analyze（ '天国で待ってない。'）\ n"、
        "＃=> [-1.0]"
      ]、
      "execution_count"：null、
      「出力」：[
        {{
          "output_type"： "execute_result"、
          "データ"： {
            "テキスト/プレーン"：[
              「[-1.0]」
            ]
          }、
          "メタデータ"：{}、
          "execution_count"：4
        }
      ]
    }、
    {{
      "cell_type"： "コード"、
      "メタデータ"：{
        "id"： "rJsQN3vQy4Ua"、
        「コラボ」：{
          "base_uri"： "https：// localhost：8080 /"
        }、
        "outputId"： "a7b8e003-57f9-4730-b292-b3d223f905ff"
      }、
      "ソース"： [
        "analyzer.analyze（ '最新刻される楽謝なししょできました。
        "＃=> [0.3333333333333333、1.0]"
      ]、
      "execution_count"：null、
      「出力」：[
        {{
          "output_type"： "execute_result"、
          "データ"： {
            "テキスト/プレーン"：[
              「[0.3333333333333333、1.0]」
            ]
          }、
          "メタデータ"：{}、
          "execution_count"：5
        }
      ]
    }、
    {{
      "cell_type"： "マークダウン"、
      "メタデータ"：{
        "id"： "Jh7KfZNXzRVT"
      }、
      "ソース"： [
        "count_polarity method
      ]
    }、
    {{
      "cell_type"： "コード"、
      "メタデータ"：{
        "id"： "FGC8ZdZkxv5h"、
        「コラボ」：{
          "base_uri"： "https：// localhost：8080 /"
        }、
        "outputId"： "7e8e58d3-ae60-4ab1-d773-24c2017ccad3"
      }、
      "ソース"： [
        "analyzer.count_polarity（ '最新刻されます楽斜事しん完了事！'）\ n"、
        "＃=> [{'ポジティブ'：2、 'ネガティブ'：1}、{'ポジティブ'：1、 'ネガティブ'：0}]）"
      ]、
      "execution_count"：null、
      「出力」：[
        {{
          "output_type"： "execute_result"、
          "データ"： {
            "テキスト/プレーン"：[
              "[{'negative'：1、 'positive'：2}、{'negative'：0、 'positive'：1}]"
            ]
          }、
          "メタデータ"：{}、
          "execution_count"：6
        }
      ]
    }、
    {{
      "cell_type"： "コード"、
      "メタデータ"：{
        "id"： "yC1yP7DHy8ww"、
        「コラボ」：{
          "base_uri"： "https：// localhost：8080 /"
        }、
        "outputId"： "7eefb9c4-746d-4779-bd6d-f61ba5c8fc13"
      }、
      "ソース"： [
        "analyzer.count_polarity（ 'アナライザー連結とワンない日常ができ。'）\ n"、
        "＃=> [{'正の'：0、 '負の'：0}]"
      ]、
      "execution_count"：null、
      「出力」：[
        {{
          "output_type"： "execute_result"、
          "データ"： {
            "テキスト/プレーン"：[
              "[{'negative'：0、 'positive'：0}]"
            ]
          }、
          "メタデータ"：{}、
          "execution_count"：7
        }
      ]
    }、
    {{
      "cell_type"： "マークダウン"、
      "メタデータ"：{
        "id"： "evoxCiztzWA5"
      }、
      "ソース"： [
        "analyze_detail
      ]
    }、
    {{
      "cell_type"： "コード"、
      "メタデータ"：{
        "id"： "FzpdRHUjzZ2h"、
        「コラボ」：{
          "base_uri"： "https：// localhost：8080 /"
        }、
        "outputId"： "15f2b295-afca-4bca-a6c5-570c4b3487ab"
      }、
      "ソース"： [
        "analyzer.analyze_detail（ '現代も希望される！'）\ n"、
        "＃=> [{'positive'：[]、 'negative'：['三重-NEGATION'、 '希望-NEGATION']、 'score'：-1.0}]）"
      ]、
      "execution_count"：null、
      「出力」：[
        {{
          "output_type"： "execute_result"、
          "データ"： {
            "テキスト/プレーン"：[
              "[{'negative'：['三重-NEGATION'、 '希望-NEGATION']、 'positive'：[]、 'score'：-1.0}]"
            ]
          }、
          "メタデータ"：{}、
          "execution_count"：8
        }
      ]
    }、
    {{
      "cell_type"： "コード"、
      "メタデータ"：{
        "id"： "Bk-462ZazjJJ"、
        「コラボ」：{
          "base_uri"： "https：// localhost：8080 /"
        }、
        "outputId"： "b4d6cf08-81e3-493c-958c-fc7ca0c81703"
      }、
      "ソース"： [
        "analyzer.analyze_detail（ 'お金がない！できない'）\ n"、
        "＃=> [{'ポジティブ'：['ポジティブ']、 'ネガティブ'：[]、 'スコア'：1.0}]"
      ]、
      "execution_count"：null、
      「出力」：[
        {{
          "output_type"： "execute_result"、
          "データ"： {
            "テキスト/プレーン"：[
              "[{'negative'：[]、 'positive'：['三重']、 'score'：1.0}]"
            ]
          }、
          "メタデータ"：{}、
          "execution_count"：9
        }
      ]
    }
  ]
}
