# %%
{"nbformat"：4、 "nbformat_minor"：0、 "metadata"：{"colab"：{"name"： "アヤメの分類.ipynb"、 "provenance"：[]、 "collapsed_sections"：[]、 " authorship_tag "：" ABX9TyNIW8A5n2k9lU59kIHBu4ih "}、" kernelspec "：{" name "：" python3 "、" display_name "：" Python 3 "}、" language_info "：{" name "：" python "}、" accelerator "：" GPU "}、" cells "：[{" cell_type "：" markdown "、" metadata "：{" id "：" chU6rT-o6sr7 "}、" source "：["アヤメのデータセットを使い、3アヤメの分類をする。\ n "、" \ n "、"その他、これらの境界線を訪問贈する "]}、{" cell_type "：" markdown "、" metadata "：{" id "：" dRi_rgYl4bnF "}、" source "：["Numpy⇒計算機能ライブラリ\ n "、" \ n "、"Pandas⇒表を当てるライブラリ\ n "、" \ n "、"Matplotlib⇒定義化ライブラリ\ n "、" \ n "、"警告⇒たまに邪魔なダウンロードを消すより "]}、{" cell_type "：" code "、" metadata "：{" id "：" omUb63vi2OE1 "}、" source "：[" import numpy as np \ n "、" import pandas as pd \ n "、" import matplotlib \ n "、" import matplotlib.pyplot as plt \ n "、"％matplotlib inline \ n "、" import warnings \ n "、" warnings.filterwarnings（ 'ignore'） "]、" execute_count "：null、" outputs "：[]}、{" cell_type "：" markdown "、" metadata "：{" id "：" 171LRXaB4pSs "}、" source "：[" 1つ目はscikit-learnに学習されたダウンロードセットです。\ n "、"scikit-learnのダウンロードセット集物にアヤメのデータセットができます。理由言いは、《学習学習のデータセットするモデルを言いする》⇒《選択的解決でありしたモデルはなんかかぁ》について機械学習度鉄板の2つの処理をしてたいからです。\ n "、" \ n "、" 3つ目が分類する。 "]}、{" cell_type "：" code "、" metadata "：{" id "：" aFk9BtkP2RPW "}、" source "：[" from sklearn.datasets import load_iris \ n "、" from sklearn.model_selection import train_test_split \ n "、" from sklearn.svm import LinearSVC "]、" execute_count "：null、" outputs "：[]}、{" cell_type "：" markdown "、" metadata "：{" id "：" dsnoMjqK4zT0 "}、" source "：["これらを生成 "]}、{" cell_type "："code"、 "metadata"：{"id"： "qultzFZY2UaV"}、 "source"：["heacet = load_iris（）"]、 "execution_count"：null、 "outputs"：[]}、{"cell_type" ： "markdown"、 "metadata"：{"id"： "9s3lD5v74z9M"}、 "source"：["データセット中身"]}、{"cell_type"： "code"、 "metadata"：{"id" ： "oWYkFUjH2XHl"}、 "source"：["print（\"パワーデータデータ\ "）\ n"、 "print（heacet.data）\ n"、 "print（heacet.data.shape）\ n" 、 "print（\" ----------------- \ "）\ n"、 "print（\"予測データ\ "）\ n"、 "print（heacet。 target）\ n "、" print（heacet.target.shape）\ n "、" print（heacet.target_names） "]、" execute_count "：null、" outputs "：[]}、{"cell_type "：" markdown "、" metadata "：{" id "：" 7Il5W5XT40vk "}、" source "：[" DataFrameの第一嵐にデータセット、第二早の列の名前を構成。\ n "、 "\ n"、 "DataFrameの最初のデータの目的変数、二叉にカラムの名前を構成。\ n"、 "\ n"、 "1と2のDataFrameを横に結合したデータフレームをこれにした"] }、{"cell_type"： "code"、 "metadata"：{"id"： "7Sjx2Qul2aEU"}、 "source"：["heacet_data = pd.DataFrame（heacet.data、columns = [\"がく片の長さ\ "、\"がく片の幅\ "、\"花びらの長さ\ "、\"花びらの幅\ "]）\ n"、 "heacet_target = pd.DataFrame（heacet.target、columns = [\ "花のメタ\"]）\ n "、" heacet_all = pd.concat（[heacet_data、heacet_target]、axis = 1） "]、" execute_count "：null、" outputs "：[]}、{" cell_type " ： "マークダウン"、 "メタデータ"：{"id"： "SHS0Dpuh43pc"}、 "source"：["ヘッドid "：" _ 21wyC372kxF "}、" source "：[" heacet_all.head（10） "]、" execute_count "：null、" outputs "：[]}、{" cell_type "：" markdown "、" metadata "： {"id"： "M5cUe1gP44D1"}、 "source"：["平均値速を出て説明説明するデータ"]}、{"cell_type"： "code"、 "metadata"：{"id"： "d7GzIJzC2xPd" }、 "source"：["heacet_all.describe（）"]、 "execution_count"：null、 "outputs"：[]}、{"cell_type"： "markdown"、 "metadata"：{"id"： "OdgGim -444kF "}、" source "：["メタデータ取得とテスト用になり "]}、{"cell_type"： "code"、 "metadata"：{"id"： "Bj3vL9K527Qt"}、 "source"：["setsumei_train、setsumei_test、mokuteki_train、mokuteki_test = train_test_split（heacet_data、heacet_target、test_size = 0.33）"]、 "execution_count"：null、 "outputs"：[]}、{"cell_type"： "markdown"、 "metadata"：{"id"： "Q2FvCmb645E1"}、 "source"：["がく片の長列車表ここ"] == 0] [\"がく片の長さ\ "]、setsumei_train [（mokuteki_train == 0）.values] [\"がく片の幅\ "]、label = \" setosa \ "、cmap = \ "rgb \"）\ n "、" plt。scatter（setsumei_train [mokuteki_train [\ "花の目\"] == 1] [\ "がく片の長さ\"]、setsumei_train [（mokuteki_train == 1）.values] [\ "がく片の幅\" ]、label = \ "versicolor \"、cmap = \ "rgb \"）\ n "、" plt.scatter（setsumei_train [mokuteki_train [\ "花の目\"] == 2] [\ "がく片の長さ\ "]、setsumei_train [（mokuteki_train == 2）.values] [\"がく片の幅\ "]、label = \" virginica \ "、cmap = \" rgb \ "）\ n"、 "\ n "、" ## X軸の範囲を指定\ n "、" plt.xlim（3,9）\ n "、" ## Y軸の範囲指定\ n "、" plt.ylim（1,5） \ n "、" \ n "、" ## X軸の名前\ n "、" plt.xlabel（\ "がく片の長さ\"）\ n "、" ## Y軸の名前\ n "、" plt .ylabel（\ "萼片の幅\"）\ n "、" \ n "、" ##列車のファイル\ n "、" plt.title（\ "がく片の長さと幅の関係\"）\ n " 、」##凡例をクリック\ n "、" plt.legend（） "]、" execute_count "：null、" outputs "：[]}、{" cell_type "：" markdown "、" metadata "：{" id "： "UWjor7fe45rU"}、 "source"：["花びらの長電車から表をする"]}、{"cell_type"： "code"、 "metadata"：{"id"： "5Ef88a5u3Spe"}、 "source" ：["plt.scatter（setsumei_train [mokuteki_train [\"花の目\ "] == 0] [\"花びらの長さ\ "]、setsumei_train [（mokuteki_train == 0）.values] [\"花びらの幅\ "]、label = \" setosa \ "、cmap = \" rgb \ "）\ n"、 "plt.scatter（setsumei_train [mokuteki_train [\"花の光\ "] == 1] [\"花びらの長さ\ "]、setsumei_train [（mokuteki_train == 1）.values] [\"花びらの幅\ "]、label = \" versicolor \ "、cmap = \" rgb \ "）\ n"、 "plt 。scatter（setsumei_train [mokuteki_train [\ "花の光\"] == 2] [\ "花びらの長さ\"]、setsumei_train [（mokuteki_train == 2）.values] [\ "花びらの幅\"]、 label = \ "virginica \"、cmap = \ "rgb \"）\ n "、" \ n "、" plt.xlim（0,8）\ n "、" plt.ylim（0,4）\ n " 、 "\ n"、 "plt.xlabel（\"花びらの長さ\ "）\ n"、 "plt.ylabel（\"花びらの幅\ "）\ n"、 "\ n"、 "plt.title（ \ "花びらの長さと幅の関係\"）\ n "、" plt.legend（） "]、" execute_count "：null、" outputs "：[]}、{" cell_type "：" markdown "、" metadata "：{" id "：" y8NzVxzs4693 "}、" source "：["注意化された2つのばら（がく片コンビと花びらコンビと花びらコンビ）の乗量を選択 "]}、{" cell_type "：" code "、 "metadata"：{"id"： "p56K68LP3Y8l "}、" source "：[" ##がく片コンビのDataFrameをできます。\ n "、" gakuhen_train = setsumei_train.loc [：、[\ "がく片の長さ\"、\ "がく片の幅\ "]] \ n"、 "\ n"、 "##花びらコンビのDataFrameをできます。\ n"、 "hanabira_train = setsumei_train.loc [：、[\"花びらの長さ\ "、\"花びらの幅\ "]]"]、 "execution_count"：null、 "outputs"：[]}、{"cell_type"： "markdown"、 "metadata"：{"id"： "fBBALzxB47vV"}、 "source" ：["モデルモデル⇒学習⇒予測"]}、{"cell_type"： "code"、 "metadata"：{"id"： "3dbzAT373ce9"}、 "source"：["##モデルモデルをした\ n "、" ##電車モデルをつく\ n "、" gakuhen_model = LinearSVC（）\ n "、" hanabira_model = LinearSVC（）\ n "、" \ n "、" ##降りのモデルに学習\ n " 、」gakuhen_model.fit（gakuhen_train、mokuteki_train）\ n "、" hanabira_model.fit（hanabira_train、mokuteki_train）\ n "、" \ n "、" ##前のモデルで予測されて、予測されてます\ n "、 "###おが《がく片の長対策》を予測してしすので、予測する時も《がく片の長測定で》をとなる定義。\ n"、 "gakuhen_predict = gakuhen_model。予測（setsumei_test.loc [：、[\ "がく片の長さ\"、\ "がく片の長さ\"、\ "がく片の幅\"]]）\ n "、" ###男が《花びらの長ベスト幅》を当ててししているので、予測する時も《花びらの長測定幅》をとなる堅断。\ n "、" hanabira_predict = hanabira_model.predict（setsumei_test.loc [：、[\ "花びらの長さ\"、 \ "花びらの]]）"]、 "execution_count"：null、 "outputs"：[]}、{"cell_type"： "markdown"、 "metadata"：{"id"： "zdR1_B0B48LF"}、 "source"：["モデルが予測予測の回答"]}、{"cell_type"： "code"、 "metadata"：{"id"： "d1eG8RT03fHt "}、" source "：[" ## sklearn.score前をした\ n "、" gakuhen_score = Accurate_score（mokuteki_test、gakuhen_predict）\ n "、" hanabira_score = Accurate_score（mokuteki_test、hanabira_predict）\ n "、" \ n "、" print（ 'がく片の長方法のコンビの正解率：{} '。format（gakuhen_score）、'花びらの長測定コンコンビの正解率：{} '。format（hanabira_score）、sep =' \\ n '） "]、" execute_count "：null、" outputs "：[]}、{" cell_type "：" markdown "、" metadata "：{" id "：" cNPXGsjd48qt "}、" source "：["《がく片の長から幅》と《花びらの長歳幅》で境界線を見る準備 "]}、{" cell_type "：" code "、" metadata "：{" id "："hHMJtrVK3lIN "}、" source "：[" def heacet_border_check（H、M、model、param1、param2、resolution = 0.01）：\ n "、" H1_min、H1_max = H [param1] .min（）-0.5、H [ param1] .max（）+ 0.5 \ n "、" H2_min、H2_max = H [param2] .min（）-0.5、H [param2] .max（）+ 0.5 \ n "、" H1、H2 = np.meshgrid （np.arange（H1_min、H1_max、resolution）、\ n "、" np.arange（H2_min、H2_max、resolution））\ n "、" n = np.array（[H1.ravel（）、H2.ravel（ ）]）。T \ n "、" Z = model.predict（n）\ n "、" Z = Z.reshape（H1.shape）\ n "、" plt.contourf（H1、H2、Z、alpha = 0.5、cmap = \ "Set2 \"）\ n "、" plt.xlim（H1_min、H1_max）\ n "、" plt.ylim（H2_min、H2_max）\ n "、" plt.xlabel（\ "Length \" ）\ n "、" plt.ylabel（\ "Width \"）\ n "、" plt。scatter（H [param1]、H [param2]、c = M [\ "花のメタ\"]、cmap = \ "brg \"） "]、" execution_count "：null、" outputs "：[]}、 {"cell_type"： "markdown"、 "metadata"：{"id"： "OXi_iwAo49bt"}、 "source"：["《がく片の長測定》"]}、{"cell_type"： "code"、 "metadata"：{"id"： "0Fn51Eaz4Pt9"}、 "source"：["heacet_border_check（setsumei_train、mokuteki_train、gakuhen_model、\"がく片の長さ\ "、\"がく片の長\ "）"]、 "execution_count"：null、 "outputs"：[]}、{"cell_type"： "markdown"、 "metadata"：{"id"： "PsI1QDvk4-KN"}、 "source"：["《花びらの長命幅》 "]}、{" cell_type "：" code "、" metadata "：{" id "：" m7lXZIah3qyU "}、"source "：[" heathet_border_check（setsumei_train、mokuteki_train、hanabira_model、\ "花びらの長さ\"、\ "花びらの長さ\"]、 "execution_count"：null、 "outputs"：[]}、{"cell_type "：" markdown "、" metadata "：{" id "：" ZmtecdPR4-9d "}、" source "：["準備： 『データの可視化されます}
